# %% [markdown]
# ## Code to Carbon Storage Model (CS)
#
# The following code iteratively runs CS model in python.

# %%
# /*===== Load libraries =====*/
import os
import logging
import sys

import natcap.invest.carbon
import natcap.invest.utils

# %%
# /*===== Preparation =====*/
model_dir_name = "CarbonStorage"
ls_ssps = ["ssp1_rcp26", "ssp3_rcp70"]
ls_years = [2030, 2035, 2040]

base_data_dir = "/Users/shunkeikakimoto/Files/base_data"

base_working_dir = base_data_dir + "/slv_InVEST_out"

# --- Path to the data directory for seals lulc --- #
seals_lulc_ssp_dir = base_data_dir + "/" + "seals_out_lulc"

# %%
for ssp in ls_ssps:

  for year in ls_years:
    # --- Path to a Working directory --- #
    work_dir = base_working_dir + "/" + ssp + "/" + model_dir_name + "/y" + str(year)

    if not os.path.exists(work_dir): os.makedirs(work_dir)

    # --- Path to a specific seals LULC file --- #
    file_path_seals_lulc_y = seals_lulc_ssp_dir + "/slv_lulc_esa_seals7_"+ ssp + "_luh2-message_bau_" + str(year) + "_clipped.tif"

    # === Run model === #
    LOGGER = logging.getLogger(__name__)
    root_logger = logging.getLogger()

    handler = logging.StreamHandler(sys.stdout)
    formatter = logging.Formatter(
      fmt=natcap.invest.utils.LOG_FMT,
      datefmt='%m/%d/%Y %H:%M:%S ')
    handler.setFormatter(formatter)
    logging.basicConfig(level=logging.INFO, handlers=[handler])

    args = {
      'calc_sequestration': False,
      'carbon_pools_path': '/Users/shunkeikakimoto/Files/base_data/mesh/biophysical_table.csv',
      'discount_rate': '',
      'do_redd': False,
      'do_valuation': False,
      # --- change this --- #
      'lulc_cur_path': file_path_seals_lulc_y,
      'lulc_cur_year': '',
      'lulc_fut_path': '',
      'lulc_fut_year': '',
      'lulc_redd_path': '',
      'price_per_metric_ton_of_c': '',
      'rate_change': '',
      'results_suffix': '',
      # --- change this --- #
      'workspace_dir': work_dir
    }

    if __name__ == '__main__':
      natcap.invest.carbon.execute(args)
# Out:
# 05/05/2024 16:00:51  (natcap.invest.carbon) carbon.execute(361) INFO Building file registry
# 05/05/2024 16:00:51  (natcap.invest.carbon) carbon.execute(406) INFO Map all carbon pools to carbon storage rasters.
# 05/05/2024 16:00:51  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_above_cur' scenario.
# 05/05/2024 16:00:51  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:51  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-4 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:51  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:51  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:51  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_below_cur' scenario.
# 05/05/2024 16:00:51  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:51  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-5 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_soil_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-6 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_dead_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-7 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(431) INFO Calculate carbon storage for 'tot_c_cur'
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-8 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(361) INFO Building file registry
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(406) INFO Map all carbon pools to carbon storage rasters.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_above_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-9 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_below_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-10 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_soil_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-11 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_dead_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-12 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(431) INFO Calculate carbon storage for 'tot_c_cur'
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-13 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(361) INFO Building file registry
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(406) INFO Map all carbon pools to carbon storage rasters.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_above_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-14 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_below_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-15 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_soil_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-16 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_dead_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-17 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(431) INFO Calculate carbon storage for 'tot_c_cur'
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-18 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(361) INFO Building file registry
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(406) INFO Map all carbon pools to carbon storage rasters.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_above_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-19 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_below_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-20 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_soil_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-21 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_dead_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-22 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(431) INFO Calculate carbon storage for 'tot_c_cur'
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-23 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(361) INFO Building file registry
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(406) INFO Map all carbon pools to carbon storage rasters.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_above_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-24 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_below_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-25 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_soil_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-26 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_dead_cur' scenario.
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-27 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:52  (natcap.invest.carbon) carbon.execute(431) INFO Calculate carbon storage for 'tot_c_cur'
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-28 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:53  (natcap.invest.carbon) carbon.execute(361) INFO Building file registry
# 05/05/2024 16:00:53  (natcap.invest.carbon) carbon.execute(406) INFO Map all carbon pools to carbon storage rasters.
# 05/05/2024 16:00:53  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_above_cur' scenario.
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-29 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:53  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_below_cur' scenario.
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-30 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:53  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_soil_cur' scenario.
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-31 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:53  (natcap.invest.carbon) carbon.execute(417) INFO Mapping carbon from 'lulc_cur_path' to 'c_dead_cur' scenario.
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-32 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:00:53  (natcap.invest.carbon) carbon.execute(431) INFO Calculate carbon storage for 'tot_c_cur'
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-33 (stats_worker), started daemon 6369079296)>
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:00:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
