# %% [markdown]
# ## Code to Nutrient Delivery Ratio (NDR) Model
#
# The following code iteratively runs CS model in python.

# %%
# /*===== Load libraries =====*/
import os
import logging
import sys

import natcap.invest.ndr.ndr
import natcap.invest.utils

# %%
# /*===== Preparation =====*/
model_dir_name = "NutrientRetention"
ls_ssps = ["ssp1_rcp26", "ssp3_rcp70"]
ls_years = [2030, 2035, 2040]

base_data_dir = "/Users/shunkeikakimoto/Files/base_data"

base_working_dir = base_data_dir + "/slv_InVEST_out"

# --- Path to the data directory for seals lulc --- #
seals_lulc_ssp_dir = base_data_dir + "/" + "seals_out_lulc"

# %%
for ssp in ls_ssps:

  for year in ls_years:
    # --- Path to a Working directory --- #
    work_dir = base_working_dir + "/" + ssp + "/" + model_dir_name + "/y" + str(year)

    if not os.path.exists(work_dir): os.makedirs(work_dir)

    # --- Path to a specific seals LULC file --- #
    file_path_seals_lulc_y = seals_lulc_ssp_dir + "/slv_lulc_esa_seals7_"+ ssp + "_luh2-message_bau_" + str(year) + "_clipped.tif"

    # === Run model === #
    LOGGER = logging.getLogger(__name__)
    root_logger = logging.getLogger()

    handler = logging.StreamHandler(sys.stdout)
    formatter = logging.Formatter(
      fmt=natcap.invest.utils.LOG_FMT,
      datefmt='%m/%d/%Y %H:%M:%S ')
    handler.setFormatter(formatter)
    logging.basicConfig(level=logging.INFO, handlers=[handler])

    args = {
      'biophysical_table_path': '/Users/shunkeikakimoto/Files/base_data/mesh/biophysical_table.csv',
      'calc_n': False,
      'calc_p': True,
      'dem_path': '/Users/shunkeikakimoto/Files/base_data/mesh/DEM/slv_elev.tif',
      'k_param': '2',
      # --- change this --- #
      'lulc_path': file_path_seals_lulc_y,
      'results_suffix': '',
      'runoff_proxy_path': '/Users/shunkeikakimoto/Files/base_data/mesh/worldclim/ppt_slv.tif',
      'subsurface_critical_length_n': '',
      'subsurface_eff_n': '',
      'threshold_flow_accumulation': '1000',
      'watersheds_path': '/Users/shunkeikakimoto/Files/base_data/mesh/hydrosheds/hydrobasin_slv_lev06.shp',
      # --- change this --- #
      'workspace_dir': work_dir,
    }

    if __name__ == '__main__':
      natcap.invest.ndr.ndr.execute(args)
# Out:
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 1 of 3 aligned: aligned_dem.tif
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 2 of 3 aligned: aligned_lulc.tif
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 3 of 3 aligned: aligned_runoff_proxy.tif
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1154) INFO aligned all 3 rasters.
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-4 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:27  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-5 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-6 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.routing.routing) Task._call(1093) INFO (fill pits): complete
# /Users/shunkeikakimoto/miniforge3/envs/env_ResEcon/lib/python3.11/site-packages/numpy/core/numeric.py:330: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# 05/05/2024 16:05:28  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow dir MFD 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow accum MFD 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.routing.routing) Task._call(1093) INFO Extract streams MFD: filter out incomplete divergent streams
# 05/05/2024 16:05:28  (pygeoprocessing.routing.routing) Task._call(1093) INFO Extract streams MFD: 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-7 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_reduce(859) INFO 100.0%% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-8 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow accum MFD 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-9 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-10 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-11 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:28  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-12 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-13 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-14 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-15 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-16 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-17 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-18 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-19 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-20 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-21 (stats_worker), started daemon 6416265216)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on reprojected.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1785) INFO Clipping rasters to their intersection with the vector
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1810) INFO calculating disjoint polygon sets
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2781) INFO build shapely polygon list
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2807) INFO build shapely rtree index
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2820) INFO poly feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2824) INFO build poly intersection lookup
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2850) INFO poly intersection feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2882) INFO maximal subset build 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1846) INFO calculating stats on raster 0 of 1
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 0 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 1 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 2 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 3 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1984) INFO all done processing polygon sets for watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on reprojected.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1785) INFO Clipping rasters to their intersection with the vector
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1810) INFO calculating disjoint polygon sets
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2781) INFO build shapely polygon list
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2807) INFO build shapely rtree index
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2820) INFO poly feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2824) INFO build poly intersection lookup
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2850) INFO poly intersection feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2882) INFO maximal subset build 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1846) INFO calculating stats on raster 0 of 1
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 0 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 1 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 2 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 3 of 4
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1984) INFO all done processing polygon sets for watershed_results_ndr.gpkg
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1015) INFO Writing summaries to output shapefile
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1019) INFO NDR complete!
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1020) INFO   _   _    ____    ____
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1021) INFO  | \ |"|  |  _"\U |  _"\ u
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1022) INFO <|  \| |>/| | | |\| |_) |/
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1023) INFO U| |\  |uU| |_| |\|  _ <
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1024) INFO  |_| \_|  |____/ u|_| \_\
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1025) INFO  ||   \\,-.|||_   //   \\_
# 05/05/2024 16:05:29  (natcap.invest.ndr.ndr) ndr.execute(1026) INFO  (_")  (_/(__)_) (__)  (__)
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on watershed_results_ndr.gpkg
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer hydrobasin_slv_lev06 of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer hydrobasin_slv_lev06 of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 1 of 3 aligned: aligned_dem.tif
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 2 of 3 aligned: aligned_lulc.tif
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 3 of 3 aligned: aligned_runoff_proxy.tif
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1154) INFO aligned all 3 rasters.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-22 (stats_worker), started daemon 6425702400)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-23 (stats_worker), started daemon 6425702400)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-24 (stats_worker), started daemon 6425702400)>
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:30  (pygeoprocessing.routing.routing) Task._call(1093) INFO (fill pits): complete
# /Users/shunkeikakimoto/miniforge3/envs/env_ResEcon/lib/python3.11/site-packages/numpy/core/numeric.py:330: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# 05/05/2024 16:05:30  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow dir MFD 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow accum MFD 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.routing.routing) Task._call(1093) INFO Extract streams MFD: filter out incomplete divergent streams
# 05/05/2024 16:05:30  (pygeoprocessing.routing.routing) Task._call(1093) INFO Extract streams MFD: 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-25 (stats_worker), started daemon 6425702400)>
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_reduce(859) INFO 100.0%% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-26 (stats_worker), started daemon 6425702400)>
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:30  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow accum MFD 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-27 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-28 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-29 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:30  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:30  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-30 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-31 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-32 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-33 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-34 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-35 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-36 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-37 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-38 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-39 (stats_worker), started daemon 6426750976)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on reprojected.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1785) INFO Clipping rasters to their intersection with the vector
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1810) INFO calculating disjoint polygon sets
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2781) INFO build shapely polygon list
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2807) INFO build shapely rtree index
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2820) INFO poly feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2824) INFO build poly intersection lookup
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2850) INFO poly intersection feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2882) INFO maximal subset build 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1846) INFO calculating stats on raster 0 of 1
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 0 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 1 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 2 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 3 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1984) INFO all done processing polygon sets for watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on reprojected.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1785) INFO Clipping rasters to their intersection with the vector
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1810) INFO calculating disjoint polygon sets
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2781) INFO build shapely polygon list
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2807) INFO build shapely rtree index
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2820) INFO poly feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2824) INFO build poly intersection lookup
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2850) INFO poly intersection feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2882) INFO maximal subset build 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1846) INFO calculating stats on raster 0 of 1
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 0 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 1 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 2 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 3 of 4
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1984) INFO all done processing polygon sets for watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1015) INFO Writing summaries to output shapefile
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer hydrobasin_slv_lev06 of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1019) INFO NDR complete!
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1020) INFO   _   _    ____    ____
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1021) INFO  | \ |"|  |  _"\U |  _"\ u
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1022) INFO <|  \| |>/| | | |\| |_) |/
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1023) INFO U| |\  |uU| |_| |\|  _ <
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1024) INFO  |_| \_|  |____/ u|_| \_\
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1025) INFO  ||   \\,-.|||_   //   \\_
# 05/05/2024 16:05:31  (natcap.invest.ndr.ndr) ndr.execute(1026) INFO  (_")  (_/(__)_) (__)  (__)
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 1 of 3 aligned: aligned_dem.tif
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 2 of 3 aligned: aligned_lulc.tif
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1150) INFO 3 of 3 aligned: aligned_runoff_proxy.tif
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.align_and_resize_raster_stack(1154) INFO aligned all 3 rasters.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-40 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-41 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-42 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:31  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer hydrobasin_slv_lev06 of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# /Users/shunkeikakimoto/miniforge3/envs/env_ResEcon/lib/python3.11/site-packages/numpy/core/numeric.py:330: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# 05/05/2024 16:05:31  (pygeoprocessing.routing.routing) Task._call(1093) INFO (fill pits): complete
# 05/05/2024 16:05:32  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow dir MFD 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow accum MFD 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.routing.routing) Task._call(1093) INFO Extract streams MFD: filter out incomplete divergent streams
# 05/05/2024 16:05:32  (pygeoprocessing.routing.routing) Task._call(1093) INFO Extract streams MFD: 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-43 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_reduce(859) INFO 100.0%% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-44 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow accum MFD 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-45 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-46 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-47 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-48 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-49 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-50 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-51 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:32  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# ...
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-97 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_reduce(859) INFO 100.0%% complete
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-98 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:37  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.routing.routing) Task._call(1093) INFO Flow accum MFD 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-99 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-100 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-101 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.routing.routing) Task._call(1093) INFO Dist to channel MFD 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-102 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-103 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-104 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-105 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-106 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-107 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-108 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-109 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-110 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-111 (stats_worker), started daemon 6427799552)>
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on reprojected.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1785) INFO Clipping rasters to their intersection with the vector
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1810) INFO calculating disjoint polygon sets
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2781) INFO build shapely polygon list
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2807) INFO build shapely rtree index
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2820) INFO poly feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2824) INFO build poly intersection lookup
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2850) INFO poly intersection feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2882) INFO maximal subset build 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1846) INFO calculating stats on raster 0 of 1
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 0 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 1 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 2 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 3 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1984) INFO all done processing polygon sets for watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2250) INFO starting reprojection
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.reproject_vector(2290) INFO reprojection 100.0% complete on reprojected.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1785) INFO Clipping rasters to their intersection with the vector
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1810) INFO calculating disjoint polygon sets
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2781) INFO build shapely polygon list
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2807) INFO build shapely rtree index
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2820) INFO poly feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2824) INFO build poly intersection lookup
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2850) INFO poly intersection feature lookup 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.calculate_disjoint_polygon_set(2882) INFO maximal subset build 100.0% complete on watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1846) INFO calculating stats on raster 0 of 1
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 0 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 1 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 2 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1856) INFO disjoint polygon set 3 of 4
# 05/05/2024 16:05:38  (pygeoprocessing.geoprocessing) geoprocessing.zonal_statistics(1984) INFO all done processing polygon sets for watershed_results_ndr.gpkg
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1015) INFO Writing summaries to output shapefile
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1019) INFO NDR complete!
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1020) INFO   _   _    ____    ____
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1021) INFO  | \ |"|  |  _"\U |  _"\ u
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1022) INFO <|  \| |>/| | | |\| |_) |/
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1023) INFO U| |\  |uU| |_| |\|  _ <
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1024) INFO  |_| \_|  |____/ u|_| \_\
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1025) INFO  ||   \\,-.|||_   //   \\_
# 05/05/2024 16:05:38  (natcap.invest.ndr.ndr) ndr.execute(1026) INFO  (_")  (_/(__)_) (__)  (__)
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer disjoint_vector of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer hydrobasin_slv_lev06 of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
