# %% [markdown]
# ## Code to Crop Pollination (CP) Model
#
# The following code iteratively runs CS model in python.

# %%
# /*===== Load libraries =====*/
import os
import logging
import sys

import natcap.invest.pollination
import natcap.invest.utils

# %%
# /*===== Preparation =====*/
model_dir_name = "CropPollination"
ls_ssps = ["ssp1_rcp26", "ssp3_rcp70"]
ls_years = [2030, 2035, 2040]

base_data_dir = "/Users/shunkeikakimoto/Files/base_data"

base_working_dir = base_data_dir + "/slv_InVEST_out"

# --- Path to the data directory for seals lulc --- #
seals_lulc_ssp_dir = base_data_dir + "/" + "seals_out_lulc"

# %%
for ssp in ls_ssps:

  for year in ls_years:
    # --- Path to a Working directory --- #
    work_dir = base_working_dir + "/" + ssp + "/" + model_dir_name + "/y" + str(year)

    if not os.path.exists(work_dir): os.makedirs(work_dir)

    # --- Path to a specific seals LULC file --- #
    file_path_seals_lulc_y = seals_lulc_ssp_dir + "/slv_lulc_esa_seals7_"+ ssp + "_luh2-message_bau_" + str(year) + "_clipped.tif"

    # === Run model === #
    LOGGER = logging.getLogger(__name__)
    root_logger = logging.getLogger()

    handler = logging.StreamHandler(sys.stdout)
    formatter = logging.Formatter(
      fmt=natcap.invest.utils.LOG_FMT,
      datefmt='%m/%d/%Y %H:%M:%S ')
    handler.setFormatter(formatter)
    logging.basicConfig(level=logging.INFO, handlers=[handler])

    args = {
      'farm_vector_path': '',
      'guild_table_path': '/Users/shunkeikakimoto/Files/base_data/mesh/guild_table.csv',
      'landcover_biophysical_table_path': '/Users/shunkeikakimoto/Files/base_data/mesh/biophysical_table.csv',
      # --- change this --- #
      'landcover_raster_path': file_path_seals_lulc_y,
      'results_suffix': '',
      # --- change this --- #
      'workspace_dir': work_dir,
    }

    if __name__ == '__main__':
      natcap.invest.pollination.execute(args)
# Out:
# 05/05/2024 17:31:21  (natcap.invest.pollination) pollination._parse_scenario_variables(1212) INFO Checking to make sure guild table has all expected headers
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-4 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-5 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-6 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-7 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-8 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_habitat_nesting_apis2 (3)) as a dependent task to this one (calculate_habitat_nesting_bombus2 (5)).
# 05/05/2024 17:31:21  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_habitat_nesting_bombus2 (5)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2030/intermediate_outputs/habitat_nesting_index_apis2.tif
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-9 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-10 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-11 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-12 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-13 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_apis_spring (7)) as a dependent task to this one (calculate_foraged_flowers_apis2_spring (9)).
# 05/05/2024 17:31:21  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_apis2_spring (9)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2030/intermediate_outputs/foraged_flowers_index_apis_spring.tif
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-14 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_apis_summer (8)) as a dependent task to this one (calculate_foraged_flowers_apis2_summer (9)).
# 05/05/2024 17:31:21  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_apis2_summer (9)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2030/intermediate_outputs/foraged_flowers_index_apis_summer.tif
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-15 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-16 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-17 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_bombus_spring (9)) as a dependent task to this one (calculate_foraged_flowers_bombus2_spring (11)).
# 05/05/2024 17:31:21  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_bombus2_spring (11)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2030/intermediate_outputs/foraged_flowers_index_bombus_spring.tif
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-18 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_bombus_summer (10)) as a dependent task to this one (calculate_foraged_flowers_bombus2_summer (11)).
# 05/05/2024 17:31:21  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_bombus2_summer (11)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2030/intermediate_outputs/foraged_flowers_index_bombus_summer.tif
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-19 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-20 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_apis.tif
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_apis.tif
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-23 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:21  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_apis.tif
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_apis.tif
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-26 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-27 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-28 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_apis2.tif
# /Users/shunkeikakimoto/miniforge3/envs/env_ResEcon/lib/python3.11/site-packages/natcap/invest/pollination.py:1077: RuntimeWarning: invalid value encountered in divide
#   foraged_flowers_array / floral_resources_array * convolve_ps_array)
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_apis2.tif
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-31 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_apis2.tif
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_apis2.tif
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-34 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-35 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-36 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_bombus.tif
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_bombus.tif
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-39 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:22  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_bombus.tif
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_bombus.tif
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-42 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-43 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-44 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_bombus2.tif
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_bombus2.tif
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-47 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_bombus2.tif
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_bombus2.tif
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-50 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-51 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-52 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-53 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (natcap.invest.pollination) pollination._parse_scenario_variables(1212) INFO Checking to make sure guild table has all expected headers
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-54 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-55 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-56 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-57 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-58 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_habitat_nesting_apis2 (3)) as a dependent task to this one (calculate_habitat_nesting_bombus2 (5)).
# 05/05/2024 17:31:23  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_habitat_nesting_bombus2 (5)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2035/intermediate_outputs/habitat_nesting_index_apis2.tif
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-59 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-60 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-61 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-62 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-63 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_apis_spring (7)) as a dependent task to this one (calculate_foraged_flowers_apis2_spring (9)).
# 05/05/2024 17:31:24  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_apis2_spring (9)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2035/intermediate_outputs/foraged_flowers_index_apis_spring.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-64 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_apis_summer (8)) as a dependent task to this one (calculate_foraged_flowers_apis2_summer (9)).
# 05/05/2024 17:31:24  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_apis2_summer (9)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2035/intermediate_outputs/foraged_flowers_index_apis_summer.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-65 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-66 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-67 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_bombus_spring (9)) as a dependent task to this one (calculate_foraged_flowers_bombus2_spring (11)).
# 05/05/2024 17:31:24  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_bombus2_spring (11)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2035/intermediate_outputs/foraged_flowers_index_bombus_spring.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-68 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (taskgraph.Task) Task.add_task(653) INFO A task was created that had an identical args signature sans target paths, but a different target_path_list of the same length. To avoid recomputation, dynamically adding previous Task (calculate_foraged_flowers_bombus_summer (10)) as a dependent task to this one (calculate_foraged_flowers_bombus2_summer (11)).
# 05/05/2024 17:31:24  (taskgraph.Task) Task.is_precalculated(1252) INFO not precalculated (calculate_foraged_flowers_bombus2_summer (11)), Task hash exists, but there are these mismatches: Recorded path not in target path list /Users/shunkeikakimoto/Files/base_data/slv_InVEST_out/ssp1_rcp26/CropPollination/y2035/intermediate_outputs/foraged_flowers_index_bombus_summer.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-69 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-70 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_apis.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_apis.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-73 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_apis.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_apis.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-76 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-77 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-78 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_apis2.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# /Users/shunkeikakimoto/miniforge3/envs/env_ResEcon/lib/python3.11/site-packages/natcap/invest/pollination.py:1077: RuntimeWarning: invalid value encountered in divide
#   foraged_flowers_array / floral_resources_array * convolve_ps_array)
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_apis2.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-81 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_apis2.tif
# 05/05/2024 17:31:24  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_apis2.tif
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-84 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-85 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:25  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# ...
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-270 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_apis.tif
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_apis.tif
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-273 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_apis.tif
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_apis.tif
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-276 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-277 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-278 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_apis2.tif
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# /Users/shunkeikakimoto/miniforge3/envs/env_ResEcon/lib/python3.11/site-packages/natcap/invest/pollination.py:1077: RuntimeWarning: invalid value encountered in divide
#   foraged_flowers_array / floral_resources_array * convolve_ps_array)
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_apis2.tif
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-281 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_apis2.tif
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_apis2.tif
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-284 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-285 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-286 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_bombus.tif
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_bombus.tif
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-289 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_bombus.tif
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_bombus.tif
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-292 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-293 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-294 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on floral_resources_bombus2.tif
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on floral_resources_bombus2.tif
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-297 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3209) INFO starting convolve
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3257) INFO 8 sent to workers, wait for worker results
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3321) INFO convolution worker 100.0% complete on convolve_ps_bombus2.tif
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3329) INFO need to normalize result so nodata values are not included
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.convolve_2d(3365) INFO convolution nodata normalize 100.0% complete on convolve_ps_bombus2.tif
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-300 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-301 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:35  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-302 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:36  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:36  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
# 05/05/2024 17:31:36  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(495) INFO starting stats_worker
# 05/05/2024 17:31:36  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(501) INFO started stats_worker <Thread(Thread-303 (stats_worker), started daemon 6288486400)>
# 05/05/2024 17:31:36  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(580) INFO 100.0% complete
# 05/05/2024 17:31:36  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(583) INFO Waiting for raster stats worker result.
